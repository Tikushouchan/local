# %%
# !pip install mecab-python3
# !pip3 install unidic-lite
# !pip install matplotlib
# !pip install japanize-matplotlib
# !pip install seaborn
# !pip install setuptools
# !pip install pandas
# !pip install sqlalchemy
# Out:
# Requirement already satisfied: mecab-python3 in ./.venv/lib/python3.12/site-packages (1.0.10)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: unidic-lite in ./.venv/lib/python3.12/site-packages (1.0.8)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: matplotlib in ./.venv/lib/python3.12/site-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.12/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.12/site-packages (from matplotlib) (4.55.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.12/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in ./.venv/lib/python3.12/site-packages (from matplotlib) (2.2.1)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.12/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in ./.venv/lib/python3.12/site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.venv/lib/python3.12/site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in ./.venv/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: japanize-matplotlib in ./.venv/lib/python3.12/site-packages (1.1.3)
# Requirement already satisfied: matplotlib in ./.venv/lib/python3.12/site-packages (from japanize-matplotlib) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.12/site-packages (from matplotlib->japanize-matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.12/site-packages (from matplotlib->japanize-matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.12/site-packages (from matplotlib->japanize-matplotlib) (4.55.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.12/site-packages (from matplotlib->japanize-matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in ./.venv/lib/python3.12/site-packages (from matplotlib->japanize-matplotlib) (2.2.1)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.12/site-packages (from matplotlib->japanize-matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in ./.venv/lib/python3.12/site-packages (from matplotlib->japanize-matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.venv/lib/python3.12/site-packages (from matplotlib->japanize-matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in ./.venv/lib/python3.12/site-packages (from matplotlib->japanize-matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->japanize-matplotlib) (1.16.0)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: seaborn in ./.venv/lib/python3.12/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in ./.venv/lib/python3.12/site-packages (from seaborn) (2.2.1)
# Requirement already satisfied: pandas>=1.2 in ./.venv/lib/python3.12/site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in ./.venv/lib/python3.12/site-packages (from seaborn) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.55.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.2)
# Requirement already satisfied: pillow>=8 in ./.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in ./.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: setuptools in ./.venv/lib/python3.12/site-packages (75.8.0)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: pandas in ./.venv/lib/python3.12/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in ./.venv/lib/python3.12/site-packages (from pandas) (2.2.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.12/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.12/site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: sqlalchemy in ./.venv/lib/python3.12/site-packages (2.0.37)
# Requirement already satisfied: typing-extensions>=4.6.0 in ./.venv/lib/python3.12/site-packages (from sqlalchemy) (4.12.2)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
import requests
from bs4 import BeautifulSoup
import time
base_url = 'https://www.jalan.net/yad302508/kuchikomi/?screenId=UWW3701&idx=0&smlCd=161802&dateUndecided=1&yadNo=302508&distCd=01'
res = requests.get(base_url)
soup = BeautifulSoup(res.content, 'html.parser')
d_list = []
reviwes = soup.find_all('div', class_='jlnpc-kuchikomiCassette__contWrap')
for reviwe in reviwes:
    comments = reviwe.find('p', class_='jlnpc-kuchikomiCassette__lead')
    stars = reviwe.find('div', class_= 'jlnpc-kuchikomiCassette__totalRate')
    print(comments.text)
    print(stars.text)

    d = {
        'comments': comments.text,
        'stars': stars.text
    }
    print(d)

    d_list.append(d)
# Out:
# 部屋の劣化が…
#
# 3
# {'comments': '\n部屋の劣化が…\n', 'stars': '3'}
#
# 接客が素晴らしい！
#
# 5
# {'comments': '\n接客が素晴らしい！\n', 'stars': '5'}
#
# 温泉がとても良かった
#
# 5
# {'comments': '\n温泉がとても良かった\n', 'stars': '5'}
#
# 部屋以外はいつもと変わらず良かったです。
#
# 4
# {'comments': '\n部屋以外はいつもと変わらず良かったです。\n', 'stars': '4'}
#
# 子連れにはもってこいの宿
#
# 4
# {'comments': '\n子連れにはもってこいの宿\n', 'stars': '4'}
#
# 冬の蓼科温泉
#
# 4
# {'comments': '\n冬の蓼科温泉\n', 'stars': '4'}
#
# ご飯が美味しい！
#
# 5
# {'comments': '\nご飯が美味しい！\n', 'stars': '5'}
#
# 初めてのガッカリ
#
# 2
# {'comments': '\n初めてのガッカリ\n', 'stars': '2'}
#
# 子連れにおすすめ
#
# 4
# {'comments': '\n子連れにおすすめ\n', 'stars': '4'}
#
# 10年ぶりに
#
# 4
# {'comments': '\n10年ぶりに\n', 'stars': '4'}
#
# 子供も大人も満足
#
# 4
# {'comments': '\n子供も大人も満足\n', 'stars': '4'}
#
# リピーター
#
# 4
# {'comments': '\nリピーター\n', 'stars': '4'}
#
# いつも素敵に楽しませてもらってます
#
# 5
# {'comments': '\nいつも素敵に楽しませてもらってます\n', 'stars': '5'}
#
# 癒やし一人旅
#
# 5
# {'comments': '\n癒やし一人旅\n', 'stars': '5'}
#
# 温泉ごはんが最高！
#
# 4
# {'comments': '\n温泉ごはんが最高！\n', 'stars': '4'}
#
# 子供も大変気に入っていました
#
# 5
# {'comments': '\n子供も大変気に入っていました\n', 'stars': '5'}
#
# 温泉でのんびり
#
# 3
# {'comments': '\n温泉でのんびり\n', 'stars': '3'}
#
# 家族旅行
#
# 4
# {'comments': '\n家族旅行\n', 'stars': '4'}
#
# 温泉良し・食事良し・景色良し
#
# 4
# {'comments': '\n温泉良し・食事良し・景色良し\n', 'stars': '4'}
#
# 全体的にとても良い
#
# 5
# {'comments': '\n全体的にとても良い\n', 'stars': '5'}
#
# 大家族旅行
#
# 1
# {'comments': '\n大家族旅行\n', 'stars': '1'}
#
# 虫が沢山
#
# 3
# {'comments': '\n虫が沢山\n', 'stars': '3'}
#
# 温泉と夕食バイキングでリピーターに
#
# 5
# {'comments': '\n温泉と夕食バイキングでリピーターに\n', 'stars': '5'}
#
# バイキングが豊富！
#
# 5
# {'comments': '\nバイキングが豊富！\n', 'stars': '5'}
#
# せせらぎのあるホテル
#
# 4
# {'comments': '\nせせらぎのあるホテル\n', 'stars': '4'}
#
# お風呂が良い
#
# 5
# {'comments': '\nお風呂が良い\n', 'stars': '5'}
#
# 病気の父の最後の旅行にと
#
# 2
# {'comments': '\n病気の父の最後の旅行にと\n', 'stars': '2'}
#
# 総合的に良いホテルです。
#
# 5
# {'comments': '\n総合的に良いホテルです。\n', 'stars': '5'}
#
# 露天風呂最高！
#
# 4
# {'comments': '\n露天風呂最高！\n', 'stars': '4'}
#
# 夕食が美味しかった
#
# 4
# {'comments': '\n夕食が美味しかった\n', 'stars': '4'}

# %%
url = 'https://www.jalan.net/yad302508/kuchikomi/{}.HTML'
for i in range(2,10):
    target_url = url.format(i)
    res = requests.get(target_url)
    print(target_url)
    soup = BeautifulSoup(res.content, 'html.parser')
    reviwes = soup.find_all('div', class_='jlnpc-kuchikomiCassette__contWrap')
    for reviwe in reviwes:
        comments = reviwe.find('p', class_='jlnpc-kuchikomiCassette__lead')
        stars = reviwe.find('div', class_= 'jlnpc-kuchikomiCassette__totalRate')
        print(comments.text)
        print(stars.text)

        d = {
            'comments': comments.text,
            'stars': stars.text
        }
        print(d)

        d_list.append(d)
    time.sleep(1)
# Out:
# https://www.jalan.net/yad302508/kuchikomi/2.HTML
#
# 食べ過ぎた！
#
# 4
# {'comments': '\n食べ過ぎた！\n', 'stars': '4'}
#
# 渓流が見える露天風呂
#
# 4
# {'comments': '\n渓流が見える露天風呂\n', 'stars': '4'}
#
# 楽しみ・悲しい・喜びの一泊
#
# 4
# {'comments': '\n楽しみ・悲しい・喜びの一泊\n', 'stars': '4'}
#
# 残念
#
# 2
# {'comments': '\n残念\n', 'stars': '2'}
#
# キッズパークがお目当てで、満足！
#
# 4
# {'comments': '\nキッズパークがお目当てで、満足！\n', 'stars': '4'}
#
# 温泉食事お部屋全て満喫しました
#
# 4
# {'comments': '\n温泉食事お部屋全て満喫しました\n', 'stars': '4'}
#
# 結婚記念日のご褒美
#
# 5
# {'comments': '\n結婚記念日のご褒美\n', 'stars': '5'}
#
# お風呂が最高でした
#
# 3
# {'comments': '\nお風呂が最高でした\n', 'stars': '3'}
#
# 子連れ家族旅行満足度星5つ
#
# 5
# {'comments': '\n子連れ家族旅行満足度星5つ\n', 'stars': '5'}
#
# キッズパークは良かった
#
# 3
# {'comments': '\nキッズパークは良かった\n', 'stars': '3'}
#
# 極普通かな
#
# 3
# {'comments': '\n極普通かな\n', 'stars': '3'}
#
# 部屋も食事も温泉も満足
#
# 5
# {'comments': '\n部屋も食事も温泉も満足\n', 'stars': '5'}
#
# ベビー、キッズにおすすめ
#
# 3
# {'comments': '\nベビー、キッズにおすすめ\n', 'stars': '3'}
#
# 部屋の狭さにビックリしました
#
# 2
# {'comments': '\n部屋の狭さにビックリしました\n', 'stars': '2'}
#
# お風呂がよかった
#
# 4
# {'comments': '\nお風呂がよかった\n', 'stars': '4'}
#
# 高いホスピタリティ
#
# 5
# {'comments': '\n高いホスピタリティ\n', 'stars': '5'}
#
# 露天風呂が最高でした。
#
# 4
# {'comments': '\n露天風呂が最高でした。\n', 'stars': '4'}
#
# お風呂が素敵
#
# 4
# {'comments': '\nお風呂が素敵\n', 'stars': '4'}
#
# 子どもが楽しんでいてよかったです！
#
# 5
# {'comments': '\n子どもが楽しんでいてよかったです！\n', 'stars': '5'}
#
# バランスの良い宿
#
# 4
# {'comments': '\nバランスの良い宿\n', 'stars': '4'}
#
# 大変良かったです
#
# 5
# {'comments': '\n大変良かったです\n', 'stars': '5'}
#
# 温泉良し・食事良し・景色良し
#
# 4
# {'comments': '\n温泉良し・食事良し・景色良し\n', 'stars': '4'}
#
# お風呂と夕食の味、品数が最高
#
# 5
# {'comments': '\nお風呂と夕食の味、品数が最高\n', 'stars': '5'}
#
# お風呂良かった！
#
# 4
# {'comments': '\nお風呂良かった！\n', 'stars': '4'}
#
# 初めて泊りましたが全てが期待以上でした！！
#
# 5
# {'comments': '\n初めて泊りましたが全てが期待以上でした！！\n', 'stars': '5'}
#
# 霧ヶ峰トレッキングの宿に最適
#
# 4
# {'comments': '\n霧ヶ峰トレッキングの宿に最適\n', 'stars': '4'}
#
# お風呂最高
#
# 4
# {'comments': '\nお風呂最高\n', 'stars': '4'}
#
# 温泉と夕食が最高
#
# 4
# {'comments': '\n温泉と夕食が最高\n', 'stars': '4'}
#
# もう一度泊まりたい！
#
# 5
# {'comments': '\nもう一度泊まりたい！\n', 'stars': '5'}
#
# 子供連れには良い宿です
#
# 4
# {'comments': '\n子供連れには良い宿です\n', 'stars': '4'}
# https://www.jalan.net/yad302508/kuchikomi/3.HTML
#
# キッズパーク
#
# 5
# {'comments': '\nキッズパーク\n', 'stars': '5'}
#
# 親も子供も楽しめるホテル
#
# 5
# {'comments': '\n親も子供も楽しめるホテル\n', 'stars': '5'}
#
# 蓼科キッズパークとカラオケ
#
# 5
# {'comments': '\n蓼科キッズパークとカラオケ\n', 'stars': '5'}
#
# 全てが満足です！
#
# 5
# {'comments': '\n全てが満足です！\n', 'stars': '5'}
#
# お風呂と食事が最高に良かったです！
#
# 5
# {'comments': '\nお風呂と食事が最高に良かったです！\n', 'stars': '5'}
#
# ホテルは綺麗
#
# 4
# {'comments': '\nホテルは綺麗\n', 'stars': '4'}
#
# すべてが満足できるホテル
#
# 5
# {'comments': '\nすべてが満足できるホテル\n', 'stars': '5'}
#
# 自営業なので夫婦で慰安旅行
#
# 5
# {'comments': '\n自営業なので夫婦で慰安旅行\n', 'stars': '5'}
#
# 孫たちが楽しそうでした。
#
# 5
# {'comments': '\n孫たちが楽しそうでした。\n', 'stars': '5'}
#
# ゴルフの後の癒し
#
# 5
# {'comments': '\nゴルフの後の癒し\n', 'stars': '5'}
#
# 子連れにおすすめ
#
# 4
# {'comments': '\n子連れにおすすめ\n', 'stars': '4'}
#
# 小学校卒業旅行
#
# 5
# {'comments': '\n小学校卒業旅行\n', 'stars': '5'}
#
# 老若男女楽しめる
#
# 5
# {'comments': '\n老若男女楽しめる\n', 'stars': '5'}
#
# 部屋・食事・風呂の三拍子とも良い
#
# 4
# {'comments': '\n部屋・食事・風呂の三拍子とも良い\n', 'stars': '4'}
#
# バリアフリー
#
# 5
# {'comments': '\nバリアフリー\n', 'stars': '5'}
#
# 5歳までの子どもにおすすめ！
#
# 4
# {'comments': '\n5歳までの子どもにおすすめ！\n', 'stars': '4'}
#
# 久しぶりの蓼科高原観光
#
# 4
# {'comments': '\n久しぶりの蓼科高原観光\n', 'stars': '4'}
#
# 食事は大満足でした。
#
# 4
# {'comments': '\n食事は大満足でした。\n', 'stars': '4'}
#
# 涼しい蓼科高原への旅
#
# 5
# {'comments': '\n涼しい蓼科高原への旅\n', 'stars': '5'}
#
# 夕食がすごく美味しい
#
# 5
# {'comments': '\n夕食がすごく美味しい\n', 'stars': '5'}
#
# お世話になりました
#
# 5
# {'comments': '\nお世話になりました\n', 'stars': '5'}
#
# 二回目の宿泊
#
# 5
# {'comments': '\n二回目の宿泊\n', 'stars': '5'}
#
# 子供も大喜び
#
# 5
# {'comments': '\n子供も大喜び\n', 'stars': '5'}
#
# 自然を満喫できました
#
# 4
# {'comments': '\n自然を満喫できました\n', 'stars': '4'}
#
# これぞ100年の歴史の宿
#
# 5
# {'comments': '\nこれぞ100年の歴史の宿\n', 'stars': '5'}
#
# 子連れにはオススメ
#
# 3
# {'comments': '\n子連れにはオススメ\n', 'stars': '3'}
#
# 良い旅行となりました
#
# 5
# {'comments': '\n良い旅行となりました\n', 'stars': '5'}
#
# 温泉に入って癒されたい方におすすめ
#
# 3
# {'comments': '\n温泉に入って癒されたい方におすすめ\n', 'stars': '3'}
#
# 5年ぶり二回目の3世代旅行
#
# 5
# {'comments': '\n5年ぶり二回目の3世代旅行\n', 'stars': '5'}
#
# 部屋を変えてもらいました
#
# 3
# {'comments': '\n部屋を変えてもらいました\n', 'stars': '3'}
# https://www.jalan.net/yad302508/kuchikomi/4.HTML
#
# 静かな宿を求める方には不向き！！！
#
# 1
# {'comments': '\n静かな宿を求める方には不向き！！！\n', 'stars': '1'}
#
# 子連れだけじゃない、みんな楽しめますよ！
#
# 5
# {'comments': '\n子連れだけじゃない、みんな楽しめますよ！\n', 'stars': '5'}
#
# 食事も温泉もとても良く、リピートでしたが・・・
#
# 4
# {'comments': '\n食事も温泉もとても良く、リピートでしたが・・・\n', 'stars': '4'}
#
# 朝食、楽しめます
#
# 3
# {'comments': '\n朝食、楽しめます\n', 'stars': '3'}
#
# 子連れにオススメ
#
# 5
# {'comments': '\n子連れにオススメ\n', 'stars': '5'}
#
# 温泉も食事も文句無し。
#
# 5
# {'comments': '\n温泉も食事も文句無し。\n', 'stars': '5'}
#
# 3世代ファミリー快適に過ごせました！
#
# 5
# {'comments': '\n3世代ファミリー快適に過ごせました！\n', 'stars': '5'}
#
# ママ友におすすめされて
#
# 3
# {'comments': '\nママ友におすすめされて\n', 'stars': '3'}
#
# 小さい子連れには
#
# 4
# {'comments': '\n小さい子連れには\n', 'stars': '4'}
#
# リバーフロントテラスは良かったです
#
# 4
# {'comments': '\nリバーフロントテラスは良かったです\n', 'stars': '4'}
#
# ごはんが美味しい
#
# 5
# {'comments': '\nごはんが美味しい\n', 'stars': '5'}
#
# 全体的に満足、でも部屋のトイレが…
#
# 4
# {'comments': '\n全体的に満足、でも部屋のトイレが…\n', 'stars': '4'}
#
# 渓流沿いの温泉宿
#
# 5
# {'comments': '\n渓流沿いの温泉宿\n', 'stars': '5'}
#
# 中学生くらいの子供と来るにはとてもよいです
#
# 5
# {'comments': '\n中学生くらいの子供と来るにはとてもよいです\n', 'stars': '5'}
#
# 露天風呂が素晴らしい
#
# 4
# {'comments': '\n露天風呂が素晴らしい\n', 'stars': '4'}
#
# 小さな子供が楽しめるホテル
#
# 5
# {'comments': '\n小さな子供が楽しめるホテル\n', 'stars': '5'}
#
# 野生の鹿が見られる露天風呂
#
# 5
# {'comments': '\n野生の鹿が見られる露天風呂\n', 'stars': '5'}
#
# バイキングが最高！
#
# 4
# {'comments': '\nバイキングが最高！\n', 'stars': '4'}
#
# お風呂が最高！！
#
# 4
# {'comments': '\nお風呂が最高！！\n', 'stars': '4'}
#
# 子連れオススメ
#
# 4
# {'comments': '\n子連れオススメ\n', 'stars': '4'}
#
# 5連泊で利用しました。居心地よく過ごすことが出来て最高でした。
#
# 5
# {'comments': '\n5連泊で利用しました。居心地よく過ごすことが出来て最高でした。\n', 'stars': '5'}
#
# お風呂最高
#
# 3
# {'comments': '\nお風呂最高\n', 'stars': '3'}
#
# 種類豊富な食事メニュー
#
# 3
# {'comments': '\n種類豊富な食事メニュー\n', 'stars': '3'}
#
# 広々とした部屋と景色が良かった。
#
# 5
# {'comments': '\n広々とした部屋と景色が良かった。\n', 'stars': '5'}
#
# お風呂が素晴らしい
#
# 3
# {'comments': '\nお風呂が素晴らしい\n', 'stars': '3'}
#
# 子連れで楽しめました
#
# 4
# {'comments': '\n子連れで楽しめました\n', 'stars': '4'}
#
# 子連れにはおすすめ、リピート確定です。
#
# 5
# {'comments': '\n子連れにはおすすめ、リピート確定です。\n', 'stars': '5'}
#
# 素晴らしいお風呂の宿
#
# 5
# {'comments': '\n素晴らしいお風呂の宿\n', 'stars': '5'}
#
# 満足！
#
# 4
# {'comments': '\n満足！\n', 'stars': '4'}
#
# 食事が美味しかった
#
# 5
# {'comments': '\n食事が美味しかった\n', 'stars': '5'}
# https://www.jalan.net/yad302508/kuchikomi/5.HTML
#
# 最高のお部屋でした！
#
# 4
# {'comments': '\n最高のお部屋でした！\n', 'stars': '4'}
#
# 母と一緒ののんびり旅
#
# 5
# {'comments': '\n母と一緒ののんびり旅\n', 'stars': '5'}
#
# ベビー&キッズを連れての旅行
#
# 4
# {'comments': '\nベビー&キッズを連れての旅行\n', 'stars': '4'}
#
# 温泉とお食事が最高♪
#
# 5
# {'comments': '\n温泉とお食事が最高♪\n', 'stars': '5'}
#
# 温泉良かった！
#
# 3
# {'comments': '\n温泉良かった！\n', 'stars': '3'}
#
# やっと行けました
#
# 4
# {'comments': '\nやっと行けました\n', 'stars': '4'}
#
# 蓼科の夏
#
# 5
# {'comments': '\n蓼科の夏\n', 'stars': '5'}
#
# 露天風呂は最高です
#
# 5
# {'comments': '\n露天風呂は最高です\n', 'stars': '5'}
#
# 人気の宿でお風呂が良い
#
# 3
# {'comments': '\n人気の宿でお風呂が良い\n', 'stars': '3'}
#
# 何度泊まってもいいな~
#
# 5
# {'comments': '\n何度泊まってもいいな~\n', 'stars': '5'}
#
# 子連れ向き
#
# 4
# {'comments': '\n子連れ向き\n', 'stars': '4'}
#
# バイキングが美味しい！
#
# 5
# {'comments': '\nバイキングが美味しい！\n', 'stars': '5'}
#
# 大きな温泉ホテル
#
# 4
# {'comments': '\n大きな温泉ホテル\n', 'stars': '4'}
#
# 子連れにおすすめ
#
# 4
# {'comments': '\n子連れにおすすめ\n', 'stars': '4'}
#
# 夕食、朝食共に品数が多く、地元料理も揃えられていて満足。
#
# 4
# {'comments': '\n夕食、朝食共に品数が多く、地元料理も揃えられていて満足。\n', 'stars': '4'}
#
# 温泉が素敵でした
#
# 4
# {'comments': '\n温泉が素敵でした\n', 'stars': '4'}
#
# 子連れにオススメ
#
# 5
# {'comments': '\n子連れにオススメ\n', 'stars': '5'}
#
# ビュッフェが美味しい！
#
# 5
# {'comments': '\nビュッフェが美味しい！\n', 'stars': '5'}
#
# 素晴らしかったです
#
# 5
# {'comments': '\n素晴らしかったです\n', 'stars': '5'}
#
# コロナ明け待って居た旅行
#
# 5
# {'comments': '\nコロナ明け待って居た旅行\n', 'stars': '5'}
#
# お孫ちゃんを連れて伺いました
#
# 4
# {'comments': '\nお孫ちゃんを連れて伺いました\n', 'stars': '4'}
#
# 迷路の様なホテルでした
#
# 4
# {'comments': '\n迷路の様なホテルでした\n', 'stars': '4'}
#
# 何より温泉
#
# 4
# {'comments': '\n何より温泉\n', 'stars': '4'}
#
# 観光
#
# 4
# {'comments': '\n観光\n', 'stars': '4'}
#
# 母が前々から行きたがっていたので(^^)
#
# 4
# {'comments': '\n母が前々から行きたがっていたので(^^)\n', 'stars': '4'}
#
# 絶景露天風呂！
#
# 5
# {'comments': '\n絶景露天風呂！\n', 'stars': '5'}
#
# お風呂の充実したお宿です。
#
# 4
# {'comments': '\nお風呂の充実したお宿です。\n', 'stars': '4'}
#
# リニューアル後とてもよかったです。
#
# 4
# {'comments': '\nリニューアル後とてもよかったです。\n', 'stars': '4'}
#
# お風呂が良いです
#
# 4
# {'comments': '\nお風呂が良いです\n', 'stars': '4'}
#
# 料理に大満足
#
# 4
# {'comments': '\n料理に大満足\n', 'stars': '4'}
# https://www.jalan.net/yad302508/kuchikomi/6.HTML
#
# 久しぶりに伺いました
#
# 4
# {'comments': '\n久しぶりに伺いました\n', 'stars': '4'}
#
# 皆んなにオススメ！文句無しの最高のお宿！
#
# 5
# {'comments': '\n皆んなにオススメ！文句無しの最高のお宿！\n', 'stars': '5'}
#
# 久しぶりに訪れました
#
# 4
# {'comments': '\n久しぶりに訪れました\n', 'stars': '4'}
#
# 雨でした
#
# 4
# {'comments': '\n雨でした\n', 'stars': '4'}
#
# 夕飯が美味しかった！
#
# 4
# {'comments': '\n夕飯が美味しかった！\n', 'stars': '4'}
#
# 大切な思い出になりました
#
# 5
# {'comments': '\n大切な思い出になりました\n', 'stars': '5'}
#
# 思い出の部屋で
#
# 3
# {'comments': '\n思い出の部屋で\n', 'stars': '3'}
#
# 景色も空気もごちそうです
#
# 4
# {'comments': '\n景色も空気もごちそうです\n', 'stars': '4'}
#
# 露天風呂付客室は最高です
#
# 5
# {'comments': '\n露天風呂付客室は最高です\n', 'stars': '5'}
#
# 渓流露天風呂気持ち良かったです
#
# 5
# {'comments': '\n渓流露天風呂気持ち良かったです\n', 'stars': '5'}
#
# 家族におすすめ、渓流露天風呂
#
# 4
# {'comments': '\n家族におすすめ、渓流露天風呂\n', 'stars': '4'}
#
# 夏にまた行きたい。
#
# 5
# {'comments': '\n夏にまた行きたい。\n', 'stars': '5'}
#
# 念願叶いました
#
# 5
# {'comments': '\n念願叶いました\n', 'stars': '5'}
#
# ゆっくり出来ました
#
# 5
# {'comments': '\nゆっくり出来ました\n', 'stars': '5'}
#
# 全体的には良いです
#
# 4
# {'comments': '\n全体的には良いです\n', 'stars': '4'}
#
# 接客がとてもよかったです！
#
# 4
# {'comments': '\n接客がとてもよかったです！\n', 'stars': '4'}
#
# 接客が良かった
#
# 4
# {'comments': '\n接客が良かった\n', 'stars': '4'}
#
# 子連れ安心の宿
#
# 5
# {'comments': '\n子連れ安心の宿\n', 'stars': '5'}
#
# 子連れにおすすめ
#
# 4
# {'comments': '\n子連れにおすすめ\n', 'stars': '4'}
#
# 品数豊富な宿
#
# 4
# {'comments': '\n品数豊富な宿\n', 'stars': '4'}
#
# 食事もお風呂も満足旅
#
# 5
# {'comments': '\n食事もお風呂も満足旅\n', 'stars': '5'}
#
# 親子で
#
# 4
# {'comments': '\n親子で\n', 'stars': '4'}
#
# 結婚38周年旅行
#
# 5
# {'comments': '\n結婚38周年旅行\n', 'stars': '5'}
#
# お子様連れ以外には厳しい宿
#
# 3
# {'comments': '\nお子様連れ以外には厳しい宿\n', 'stars': '3'}
#
# 子連れには良いかも
#
# 5
# {'comments': '\n子連れには良いかも\n', 'stars': '5'}
#
# 子連れ旅行
#
# 4
# {'comments': '\n子連れ旅行\n', 'stars': '4'}
#
# ホテルの中がとても綺麗だった
#
# 4
# {'comments': '\nホテルの中がとても綺麗だった\n', 'stars': '4'}
#
# やっぱり最高
#
# 4
# {'comments': '\nやっぱり最高\n', 'stars': '4'}
#
# すべてが最高でした。
#
# 5
# {'comments': '\nすべてが最高でした。\n', 'stars': '5'}
#
# 夕食の給仕さん、良かった〜
#
# 5
# {'comments': '\n夕食の給仕さん、良かった〜\n', 'stars': '5'}
# https://www.jalan.net/yad302508/kuchikomi/7.HTML
#
# ゆっくりできました。
#
# 4
# {'comments': '\nゆっくりできました。\n', 'stars': '4'}
#
# お風呂と食事がおすすめ
#
# 4
# {'comments': '\nお風呂と食事がおすすめ\n', 'stars': '4'}
#
# 接客以外は満足でした
#
# 3
# {'comments': '\n接客以外は満足でした\n', 'stars': '3'}
#
# 露天風呂最高、鹿も見えました。
#
# 5
# {'comments': '\n露天風呂最高、鹿も見えました。\n', 'stars': '5'}
#
# 二度目の再訪
#
# 5
# {'comments': '\n二度目の再訪\n', 'stars': '5'}
#
# 良かった
#
# 5
# {'comments': '\n良かった\n', 'stars': '5'}
#
# 料理と風呂最高
#
# 4
# {'comments': '\n料理と風呂最高\n', 'stars': '4'}
#
# バイキングだけどレベル高い
#
# 4
# {'comments': '\nバイキングだけどレベル高い\n', 'stars': '4'}
#
# 少し残念でした。
#
# 3
# {'comments': '\n少し残念でした。\n', 'stars': '3'}
#
# ファミリー層が多く安心
#
# 5
# {'comments': '\nファミリー層が多く安心\n', 'stars': '5'}
#
# リラックス出来る宿
#
# 5
# {'comments': '\nリラックス出来る宿\n', 'stars': '5'}
#
# 子連れには最高！
#
# 5
# {'comments': '\n子連れには最高！\n', 'stars': '5'}
#
# お食事は最高！
#
# 4
# {'comments': '\nお食事は最高！\n', 'stars': '4'}
#
# 基本プラン　季節の料理と温泉
#
# 4
# {'comments': '\n基本プラン\u3000季節の料理と温泉\n', 'stars': '4'}
#
# 親子３代３家族で親睦旅行
#
# 3
# {'comments': '\n親子３代３家族で親睦旅行\n', 'stars': '3'}
#
# 又、何度も行きたいホテルです。
#
# 5
# {'comments': '\n又、何度も行きたいホテルです。\n', 'stars': '5'}
#
# 温泉最高 接客微妙
#
# 3
# {'comments': '\n温泉最高 接客微妙\n', 'stars': '3'}
#
# 子連れへの配慮に脱帽
#
# 5
# {'comments': '\n子連れへの配慮に脱帽\n', 'stars': '5'}
#
# 部屋が広くきもちがよかった。
#
# 3
# {'comments': '\n部屋が広くきもちがよかった。\n', 'stars': '3'}
#
# 色々な風呂が楽しめ、料理の品数が豊富
#
# 4
# {'comments': '\n色々な風呂が楽しめ、料理の品数が豊富\n', 'stars': '4'}
#
# フロントが低レベル
#
# 3
# {'comments': '\nフロントが低レベル\n', 'stars': '3'}
#
# 自分へのご褒美として選んだ宿
#
# 5
# {'comments': '\n自分へのご褒美として選んだ宿\n', 'stars': '5'}
#
# いつ行っても良いホテル
#
# 5
# {'comments': '\nいつ行っても良いホテル\n', 'stars': '5'}
#
# 露天風呂が最高でした。
#
# 5
# {'comments': '\n露天風呂が最高でした。\n', 'stars': '5'}
#
# 全体的には素晴らしい宿
#
# 3
# {'comments': '\n全体的には素晴らしい宿\n', 'stars': '3'}
#
# 心遣いに感謝です
#
# 5
# {'comments': '\n心遣いに感謝です\n', 'stars': '5'}
#
# 子供連れにおすすめ  食事がバイキングなので、好きなモノを食べれる
#
# 3
# {'comments': '\n子供連れにおすすめ\xa0\xa0食事がバイキングなので、好きなモノを食べれる\n', 'stars': '3'}
#
# 安定のクオリティ
#
# 5
# {'comments': '\n安定のクオリティ\n', 'stars': '5'}
#
# 家族旅行で利用
#
# 1
# {'comments': '\n家族旅行で利用\n', 'stars': '1'}
#
# バイキングが好き
#
# 4
# {'comments': '\nバイキングが好き\n', 'stars': '4'}
# https://www.jalan.net/yad302508/kuchikomi/8.HTML
#
# 露天風呂がgood
#
# 3
# {'comments': '\n露天風呂がgood\n', 'stars': '3'}
#
# 子連れにオススメ
#
# 4
# {'comments': '\n子連れにオススメ\n', 'stars': '4'}
#
# 温泉堪能しました
#
# 4
# {'comments': '\n温泉堪能しました\n', 'stars': '4'}
#
# 冷蔵庫だけが残念
#
# 3
# {'comments': '\n冷蔵庫だけが残念\n', 'stars': '3'}
#
# 子供も大人も大満足
#
# 5
# {'comments': '\n子供も大人も大満足\n', 'stars': '5'}
#
# 子供たちの天国です
#
# 5
# {'comments': '\n子供たちの天国です\n', 'stars': '5'}
#
# おもてなしがとても親切で良い思い出になりました
#
# 5
# {'comments': '\nおもてなしがとても親切で良い思い出になりました\n', 'stars': '5'}
#
# 食事が美味しい
#
# 4
# {'comments': '\n食事が美味しい\n', 'stars': '4'}
#
# 食事が美味しかった！
#
# 4
# {'comments': '\n食事が美味しかった！\n', 'stars': '4'}
#
# ほぼ完璧も、ご飯だけが質を下げている。
#
# 4
# {'comments': '\nほぼ完璧も、ご飯だけが質を下げている。 \n', 'stars': '4'}
#
# 子連れにおすすめ
#
# 5
# {'comments': '\n子連れにおすすめ\n', 'stars': '5'}
#
# 朝夕ビュッフェ、お部屋、お風呂大満足!
#
# 5
# {'comments': '\n朝夕ビュッフェ、お部屋、お風呂大満足!\n', 'stars': '5'}
#
# お部屋が良かった！
#
# 5
# {'comments': '\nお部屋が良かった！\n', 'stars': '5'}
#
# 子供が大喜び、親も安心して楽しめる宿です。
#
# 5
# {'comments': '\n子供が大喜び、親も安心して楽しめる宿です。\n', 'stars': '5'}
#
# 子供も親も喜ぶホテルです
#
# 5
# {'comments': '\n子供も親も喜ぶホテルです\n', 'stars': '5'}
#
# 温泉が多彩
#
# 4
# {'comments': '\n温泉が多彩\n', 'stars': '4'}
#
# 子連れには良いホテルです
#
# 3
# {'comments': '\n子連れには良いホテルです\n', 'stars': '3'}
#
# 家族旅行にはとても良いです
#
# 4
# {'comments': '\n家族旅行にはとても良いです\n', 'stars': '4'}
#
# 総合的には良いけど…
#
# 4
# {'comments': '\n総合的には良いけど…\n', 'stars': '4'}
#
# 時間いっぱい楽しみました
#
# 5
# {'comments': '\n時間いっぱい楽しみました\n', 'stars': '5'}
#
# 癒やされました！
#
# 5
# {'comments': '\n癒やされました！\n', 'stars': '5'}
#
# 施設他
#
# 4
# {'comments': '\n施設他\n', 'stars': '4'}
#
# 滝の湯好きの夫婦です
#
# 4
# {'comments': '\n滝の湯好きの夫婦です\n', 'stars': '4'}
#
# 姪っ子ちゃん満足
#
# 5
# {'comments': '\n姪っ子ちゃん満足\n', 'stars': '5'}
#
# 大雪
#
# 4
# {'comments': '\n大雪\n', 'stars': '4'}
#
# 三世代誕生日旅行
#
# 5
# {'comments': '\n三世代誕生日旅行\n', 'stars': '5'}
#
# 昔より悪くなった
#
# 2
# {'comments': '\n昔より悪くなった\n', 'stars': '2'}
#
# 久しぶり!
#
# 5
# {'comments': '\n久しぶり!\n', 'stars': '5'}
#
# 子供の卒業旅行で
#
# 5
# {'comments': '\n子供の卒業旅行で\n', 'stars': '5'}
#
# 子連れにおすすめ
#
# 5
# {'comments': '\n子連れにおすすめ\n', 'stars': '5'}
# https://www.jalan.net/yad302508/kuchikomi/9.HTML
#
# 雪を観ながらの渓流露天風呂
#
# 5
# {'comments': '\n雪を観ながらの渓流露天風呂\n', 'stars': '5'}
#
# 良いホテル
#
# 5
# {'comments': '\n良いホテル\n', 'stars': '5'}
#
# 以前よりも悪くなっていた。。。
#
# 2
# {'comments': '\n以前よりも悪くなっていた。。。\n', 'stars': '2'}
#
# やはり、滝の湯はお風呂が最高！
#
# 5
# {'comments': '\nやはり、滝の湯はお風呂が最高！\n', 'stars': '5'}
#
# リーズナブル
#
# 4
# {'comments': '\nリーズナブル\n', 'stars': '4'}
#
# 残念な思い
#
# 1
# {'comments': '\n残念な思い\n', 'stars': '1'}
#
# お風呂
#
# 4
# {'comments': '\nお風呂\n', 'stars': '4'}
#
# 子連れで宿泊しました。
#
# 4
# {'comments': '\n子連れで宿泊しました。\n', 'stars': '4'}
#
# 温泉最高
#
# 5
# {'comments': '\n温泉最高\n', 'stars': '5'}

# %%
print(len(d_list))
# Out:
# 249

# %%
import pandas as pd
import MeCab

# 感情値辞書の読み込み
url = "http://www.lr.pi.titech.ac.jp/~takamura/pubs/pn_ja.dic"
response = requests.get(url)
# テキストを直接読み込む
lines = response.content.decode("shift-jis").split("\n")

# 辞書の作成
pndic = {}
for line in lines:
    parts = line.split(':')
    if len(parts) == 4:
        word = parts[0]
        score = float(parts[3])
        pndic[word] = score

# MeCabのTaggerオブジェクトを作成
tagger = MeCab.Tagger()

# 感情スコアを算出する関数
def calculate_sentiment_score(review, dic):
    node = tagger.parseToNode(review)
    score = 0
    word_count = 0

    while node:
        word = node.surface
        if word in dic:
            score += dic[word]
            word_count += 1
        node = node.next
    
    # 平均スコアを計算
    if word_count > 0:
        avg_score = score / word_count
    else:
        avg_score = 0
    
    return avg_score

# %%
# 各口コミの感情スコアを計算して追加
for d in d_list:
    sentiment_score = calculate_sentiment_score(d['comments'], pndic)
    d['sentiment_score'] = sentiment_score

# DataFrameにして表示
reviews_df = pd.DataFrame(d_list, columns=["comments", "stars", "sentiment_score"])
print(reviews_df)
# Out:
#                      comments stars  sentiment_score
# 0                 \n部屋の劣化が…\n     3        -0.963416
# 1               \n接客が素晴らしい！\n     5         0.394372
# 2              \n温泉がとても良かった\n     5        -0.446536
# 3    \n部屋以外はいつもと変わらず良かったです。\n     4        -0.582710
# 4            \n子連れにはもってこいの宿\n     4        -0.587177
# ..                        ...   ...              ...
# 244                \nリーズナブル\n     4         0.000000
# 245                 \n残念な思い\n     1        -0.837311
# 246                   \nお風呂\n     4        -0.629613
# 247           \n子連れで宿泊しました。\n     4        -0.595816
# 248                  \n温泉最高\n     5        -0.583507
#
# [249 rows x 3 columns]

# %%
import sqlite3
from sqlalchemy import create_engine
# SQLiteデータベースに接続
engine = create_engine('sqlite:///reviews.db')

# テーブル名を指定してDataFrameをDBに挿入
reviews_df.to_sql('reviews', con=engine, if_exists='replace', index=False)
reviews_df = reviews_df.sort_values(by=['stars'])

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import japanize_matplotlib

# SQLAlchemyを使用してDBにクエリを発行しデータ取得
query = "SELECT * FROM reviews"
reviews_from_db = pd.read_sql(query, con=engine)

grouped_df = reviews_from_db.groupby('stars').agg({'sentiment_score': ['mean', 'std']}).reset_index()
grouped_df.columns = ['stars', 'mean_sentiment_score', 'std_sentiment_score']

print(grouped_df)

plt.figure(figsize=(10, 6))
plt.bar(grouped_df['stars'], grouped_df['mean_sentiment_score'], yerr=grouped_df['std_sentiment_score'], capsize=5, color='skyblue')
plt.title('星ごとの感情スコアの平均と標準偏差')
plt.xlabel('星')
plt.ylabel('感情スコアの平均')
plt.grid(True)

plt.show()
# Out:
#   stars  mean_sentiment_score  std_sentiment_score
# 0     1             -0.754042             0.139217
# 1     2             -0.888410             0.114318
# 2     3             -0.463965             0.369142
# 3     4             -0.346074             0.329738
# 4     5             -0.251726             0.433604

# %%
correlation = reviews_from_db['stars'].corr(reviews_from_db['sentiment_score'])
print(f"星の数と感情スコアの相関係数: {correlation}")
# Out:
# 星の数と感情スコアの相関係数: 0.29087844869253865
